# %% [markdown]
# ## Computer Vision Fundamentals

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load image and Check image dimensions

# %%
image = cv2.imread("cat.png")
print(image.shape)
# Out:
# (1000, 666, 3)

# %% [markdown]
# ## Show the image

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.show()

# %% [markdown]
# ## Resize image

# %%
resized = cv2.resize(image_rgb, (128, 128))

plt.imshow(resized)
plt.show()

print(resized.shape)
# Out:
# (128, 128, 3)

# %% [markdown]
# ## Normalize image

# %%
normalized = resized / 255.0

print(normalized.min())
print(normalized.max())
# Out:
# 0.0
# 0.9882352941176471

# %% [markdown]
# ## Convert to grayscale

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

plt.imshow(gray, cmap="gray")
plt.show()

print(gray.shape)
# Out:
# (1000, 666)

# %%
def preprocess_image(path):
    image = cv2.imread(path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    resized = cv2.resize(image_rgb, (128, 128))
    normalized = resized / 255.0
    return normalized

# %%
processed = preprocess_image("cat.png")

plt.imshow(processed)
plt.show()

print(processed.shape)
print(processed.min())
print(processed.max())
# Out:
# (128, 128, 3)
# 0.0
# 0.9882352941176471
