# %% [markdown]
# ## Step 1 Install YOLO
# It installs:
#
# YOLO
# PyTorch dependencies
# object detection tools

# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (8.4.51)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from ultralytics) (2.4.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from ultralytics) (3.10.9)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from ultralytics) (12.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from ultralytics) (2.34.2)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from ultralytics) (1.17.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from ultralytics) (2.12.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from ultralytics) (0.27.0)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from ultralytics) (1.40.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from ultralytics) (2.0.19)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=3 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.40.1 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from polars>=0.20.0->ultralytics) (1.40.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from requests>=2.23.0->ultralytics) (3.15)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from requests>=2.23.0->ultralytics) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from requests>=2.23.0->ultralytics) (2026.4.22)
# Requirement already satisfied: filelock in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from torch>=1.8.0->ultralytics) (65.5.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from torch>=1.8.0->ultralytics) (2026.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sivaguduri\desktop\learn-ml\dl-env\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Step 2 Import

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\SivaGuduri\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# ## Step 3 Load pretrained model

# %%
model = YOLO("yolov8n.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 6.9MB/s 0.9s.9s<0.0ss.8s

# %% [markdown]
# ## Step 4 Test with sample image

# %%
results = model("bus.jpg")
# Out:
# image 1/1 C:\Users\SivaGuduri\Desktop\learn-ML\ComputerVision\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 144.6ms
# Speed: 3.7ms preprocess, 144.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)

# %% [markdown]
# ## Step 5 Show result

# %%
results[0].show()
