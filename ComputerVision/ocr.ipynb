# %% [markdown]
# ## Step 1 — Import

# %%
import easyocr
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 2 — Create OCR reader
# loads pretrained OCR model

# %%
reader = easyocr.Reader(['en'])
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %% [markdown]
# ## Step 3 — Test with image containing text

# %%
result = reader.readtext("invite_note.jpg")
for item in result:
    print(item[1])
# Out:
# C:\Users\SivaGuduri\Desktop\learn-ML\dl-env\Lib\site-packages\torch\utils\data\dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# You are invited to
# BIRFHDAY
# PARTY
# Saylee
# Sth
# Taj Hotel; Banglore. Dinner
# Zpm onwards:
# January 01 2024
# Monday 12:00 AM
# RSVP to 123-456-7890
